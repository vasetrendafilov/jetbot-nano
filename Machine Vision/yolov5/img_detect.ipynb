# %%
weights = r'runs\train\yolo5n-150e-15b\weights\best.pt'
sorce = r'C:\Users\vase_\Downloads\jetbot-nano\Data\snapshots\test'

# %%
# !python detect.py --weights {weights} --img 416 --source {sorce} --save-txt
# Out:
# detect: weights=['runs\\train\\yolo5n-150e-15b\\weights\\best.pt'], source=C:\Users\vase_\Downloads\jetbot-nano\Data\snapshots\test, data=data\coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# fatal: cannot change to 'C:\Users\vase_\Downloads\jetbot-nano\Machine': No such file or directory
# YOLOv5  2022-6-4 Python-3.9.7 torch-1.11.0+cpu CPU
#
# Fusing layers...
# Model summary: 213 layers, 1761871 parameters, 0 gradients, 4.2 GFLOPs
# image 1/201 C:\Users\vase_\Downloads\jetbot-nano\Data\snapshots\test\510.jpg: 320x416 1 black, 1 me, Done. (0.139s)
# image 2/201 C:\Users\vase_\Downloads\jetbot-nano\Data\snapshots\test\511.jpg: 320x416 1 black, 1 me, Done. (0.138s)
# ...
